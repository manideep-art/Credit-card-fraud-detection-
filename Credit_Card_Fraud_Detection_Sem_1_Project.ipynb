# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0     0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62    0.0
# 1     0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69    0.0
# 2     1 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66    0.0
# 3     1 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50    0.0
# 4     2 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#       Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 1981  1524 -0.340622  1.132232  1.291494  ...  0.245128  0.098336    5.35    0.0
# 1982  1525 -1.842696  1.740641  0.861526  ...  0.586012  0.352610    1.00    0.0
# 1983  1525 -0.480693  0.646091  1.577264  ... -0.015602  0.051504   80.70    0.0
# 1984  1525 -0.342132  1.091125  1.282729  ...  0.241932  0.097139    3.59    0.0
# 1985  1526 -0.854343  1.382948  1.278665  ...       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    1986 non-null   int64
#  1   V1      1986 non-null   float64
#  2   V2      1986 non-null   float64
#  3   V3      1986 non-null   float64
#  4   V4      1986 non-null   float64
#  5   V5      1986 non-null   float64
#  6   V6      1986 non-null   float64
#  7   V7      1986 non-null   float64
#  8   V8      1986 non-null   float64
#  9   V9      1986 non-null   float64
#  10  V10     1986 non-null   float64
#  11  V11     1986 non-null   float64
#  12  V12     1986 non-null   float64
#  13  V13     1986 non-null   float64
#  14  V14     1985 non-null   float64
#  15  V15     1985 non-null   float64
#  16  V16     1985 non-null   float64
#  17  V17     1985 non-null   float64
#  18  V18     1985 non-null   float64
#  19  V19     1985 non-null   float64
#  20  V20     1985 non-null   float64
#  21  V21     1985 non-null   float64
#  22  V22     1985 non-null   float64
#  23  V23     1985 non-null   float64
#  24  V24     1985 non-null   float64
#  25  V25     1985 non-null   float64
#  26  V26     1985 non-null   float64
#  27  V27     1985 non-null   float64
#  28  V28     1985 non-null   float64
#  29  Amount  1985 non-null   float64
#  30  Class   1985 non-null   float64
# dtypes: float64(30), int64(1)
# memory usage: 481.1 KB

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    1983
# 1.0       2
# Name: Class, dtype: int64

# %% [markdown]
# This Dataset is highly unblanced
#
# 0 --> Normal Transaction
#
# 1 --> fraudulent transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (1983, 31)
# (2, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    1983.000000
# mean       68.404892
# std       241.572682
# min         0.000000
# 25%         4.950000
# 50%        15.090000
# 75%        63.285000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      2.000000
# mean     264.500000
# std      374.059487
# min        0.000000
# 25%      132.250000
# 50%      264.500000
# 75%      396.750000
# max      529.000000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#              Time        V1        V2  ...       V27       V28      Amount
# Class                                  ...
# 0.0    760.974786 -0.281494  0.267200  ...  0.027220 -0.001966   68.404892
# 1.0    439.000000 -2.677884 -0.602658  ...  0.004186 -0.053756  264.500000
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling
#
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions
#
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#       Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 1448  1124  1.032034 -0.690951 -0.564275  ... -0.057110  0.017310  160.00    0.0
# 672    509 -0.404841  1.005372  1.372756  ...  0.234036  0.088356    8.28    0.0
# 1898  1467 -1.673025  1.006263  0.726009  ...  0.089001 -0.025177   64.61    0.0
# 448    325  1.409186 -0.383686  0.256252  ... -0.047751  0.010905   17.24    0.0
# 1791  1395  1.228507 -0.070446  0.198873  ... -0.022719 -0.001570   23.95    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#       Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 690    522 -0.608941  0.961271  0.978330  ...  0.051356  0.083632   39.05    0.0
# 111     73  1.148187  0.085837  0.120702  ...  0.031507  0.000372   19.77    0.0
# 1360  1056 -0.409935  1.085135  1.280776  ...  0.264674  0.096800    2.28    0.0
# 541    406 -2.312227  1.951992 -1.609851  ...  0.261145 -0.143276    0.00    1.0
# 623    472 -3.043541 -3.157307  1.088463  ... -0.252773  0.035764  529.00    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    492
# 1.0      2
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#              Time        V1        V2  ...       V27       V28      Amount
# Class                                  ...
# 0.0    761.585366 -0.312982  0.283304  ...  0.035232  0.008914   61.896341
# 1.0    439.000000 -2.677884 -0.602658  ...  0.004186 -0.053756  264.500000
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features & Targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#       Time        V1        V2        V3  ...       V26       V27       V28  Amount
# 1448  1124  1.032034 -0.690951 -0.564275  ...  0.002236 -0.057110  0.017310  160.00
# 672    509 -0.404841  1.005372  1.372756  ...  0.044937  0.234036  0.088356    8.28
# 1898  1467 -1.673025  1.006263  0.726009  ... -0.269256  0.089001 -0.025177   64.61
# 448    325  1.409186 -0.383686  0.256252  ...  0.929543 -0.047751  0.010905   17.24
# 1791  1395  1.228507 -0.070446  0.198873  ...  0.233448 -0.022719 -0.001570   23.95
# ...    ...       ...       ...       ...  ...       ...       ...       ...     ...
# 690    522 -0.608941  0.961271  0.978330  ... -0.401181  0.051356  0.083632   39.05
# 111     73  1.148187  0.085837  0.120702  ... -0.288035  0.031507  0.000372   19.77
# 1360  1056 -0.409935  1.085135  1.280776  ...  0.099748  0.264674  0.096800    2.28
# 541    406 -2.312227  1.951992 -1.609851  ...  0.177840  0.261145 -0.143276    0.00
# 623    472 -3.043541 -3.157307  1.088463  ... -0.145362 -0.252773  0.035764  529.00
#
# [494 rows x 30 columns]

# %%
print(Y)
# Out:
# 1448    0.0
# 672     0.0
# 1898    0.0
# 448     0.0
# 1791    0.0
#        ...
# 690     0.0
# 111     0.0
# 1360    0.0
# 541     1.0
# 623     1.0
# Name: Class, Length: 494, dtype: float64

# %% [markdown]
# Split the data into Training data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (494, 30) (395, 30) (99, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  1.0

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.98989898989899
